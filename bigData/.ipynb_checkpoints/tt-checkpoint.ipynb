# %%
from pyspark import SparkContext, SparkConf

sc.stop()
conf = SparkConf().setAppName("spark_mlib")
sc = SparkContext(conf=conf)

file = 'file:/home/hadoop/PycharmProjects/pythonProject/data/'

rawData = sc.textFile(file+'hour.csv')
header = rawData.first()
rData = rawData.filter(lambda x: x != header)

lines = rData.map(lambda x: x.split(","))
print("共有： " + str(lines.count()) + "项数据")
# Out:
# 共有： 17379项数据

# %%
# 处理特征
import numpy as np

def convert_float(v):
    """处理数值，将字符串转为float"""
    return float(v)

def process_features(line):
    """处理特征，line为字段行"""
    SeasonFeature = [convert_float(value) for value in line[2]]
    ## 处理余下的特征
    Features = [convert_float(value) for value in line[4: 14]]
    
    return Features

# %%
# 处理预测目标值
def process_label(line):
    return float(line[-1])
process_label(lines.first())
# Out:
# 16.0

# %%
# 构建LabelPoint数据
from pyspark.mllib.regression import LabeledPoint

labelpointRDD = lines.map(lambda r: LabeledPoint(process_label(r), \
                                                process_features(r)))

labelpointRDD.first()
# Out:
# LabeledPoint(16.0, [1.0,0.0,0.0,6.0,0.0,1.0,0.24,0.2879,0.81,0.0])

# %%
# 划分数据集、验证集和测试集
(trainData, validationData, testData) = labelpointRDD.randomSplit([7, 1, 2])
print("训练集样本个数："+str(trainData.count()) + " 验证集样本个数：" + str(validationData.count()) + ' 测试集样本个数：' + str(testData.count()))

# 将数据暂存在内存中，加快后续运算效率
trainData.persist()
validationData.persist()
testData.persist()
# Out:
# 训练集样本个数：12165 验证集样本个数：1749 测试集样本个数：3465
# PythonRDD[21] at RDD at PythonRDD.scala:53

# %%
from pyspark.mllib.tree import DecisionTree
model = DecisionTree.trainRegressor(trainData, categoricalFeaturesInfo={}, impurity="variance", maxDepth=5,
                                   minInstancesPerNode=1, minInfoGain=0.0)

# %%
## 使用RMSE对模型进行评估
import numpy as np
from pyspark.mllib.evaluation import RegressionMetrics

## 定义模型评估函数
def RMSE(model, validationData):
    ## 计算模型的准确率
    predict = model.predict(validationData.map(lambda p:p.features))
    ## 拼接预测值和实际值
    predict_real = predict.zip(validationData.map(lambda p: p.label))
    ## 计算均方误差
    rmse = np.sqrt(predict_real.map(lambda p: (p[0]-p[1])**2).sum() / predict_real.count())
    return rmse

## 调用函数求模型在验证集上的准确率
rmse =  RMSE(model, validationData)
print("均方误差RMSE="+str(rmse))
# Out:
# 均方误差RMSE=117.07152560810287

# %%
## 创建trainEvaluateModel函数包含训练与评估功能，并计算训练评估的时间。
import time

def trainEvaluateModel(trainData, validationData, maxDepthParm, maxBinsParm, minInstancesPerNodeParm, minInfoGainParm):
    startTime = time.time()
    ## 创建并训练模型
    model = DecisionTree.trainRegressor(trainData, categoricalFeaturesInfo={}, impurity="variance", maxDepth=maxDepthParm, 
                                        maxBins=maxBinsParm, minInstancesPerNode=minInstancesPerNodeParm, minInfoGain=minInfoGainParm)
    ## 计算RMSE
    rmse = RMSE(model, validationData)
    duration = time.time() - startTime   # 持续时间
    print("训练评估：参数"+ ",  maxDepth="+str(maxDepthParm)+",  maxBins="+str(maxBinsParm)+ 
          ", minInstancesPerNode="+str(minInstancesPerNodeParm) +", minInfoGainParm="+str(minInfoGainParm)+"\n"
         "===>消耗时间="+str(duration)+",  均方误差RMSE="+str(rmse))
    return rmse, duration, maxDepthParm, maxBinsParm, minInstancesPerNodeParm, minInfoGainParm, model

# %%
## 评估参数 maxDepth
maxDepthList = [3,5, 10, 15, 20,25]
maxBinsList = [10]
minInstancesPerNodeList=[1]
minInfoGainList=[0.0]

## 返回结果存放至metries中
metrics = [trainEvaluateModel(trainData, validationData, maxDepth, maxBins, minInstancesPerNode, minInfoGain)
          for maxDepth in maxDepthList
          for maxBins in maxBinsList
          for minInstancesPerNode in minInstancesPerNodeList
          for minInfoGain in minInfoGainList]
# Out:
# 训练评估：参数,  maxDepth=3,  maxBins=10, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=1.0656483173370361,  均方误差RMSE=136.68573954526283
# 训练评估：参数,  maxDepth=5,  maxBins=10, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=0.8226358890533447,  均方误差RMSE=117.89539783083941
# 训练评估：参数,  maxDepth=10,  maxBins=10, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=1.2596476078033447,  均方误差RMSE=92.78990914881749
# 训练评估：参数,  maxDepth=15,  maxBins=10, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=1.8064186573028564,  均方误差RMSE=101.65582131413692
# 训练评估：参数,  maxDepth=20,  maxBins=10, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=2.6871588230133057,  均方误差RMSE=109.8908807760606
# 训练评估：参数,  maxDepth=25,  maxBins=10, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=3.9405529499053955,  均方误差RMSE=110.5965520504858

# %%
## 评估参数 maxBins
maxDepthList = [10]
maxBinsList = [5,10,15,100,200,500]
minInstancesPerNodeList=[1]
minInfoGainList=[0.0]

## 返回结果存放至metries中
metrics = [trainEvaluateModel(trainData, validationData, maxDepth, maxBins, minInstancesPerNode, minInfoGain)
          for maxDepth in maxDepthList
          for maxBins in maxBinsList
          for minInstancesPerNode in minInstancesPerNodeList
          for minInfoGain in minInfoGainList]
# Out:
# 训练评估：参数,  maxDepth=10,  maxBins=5, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=0.9183893203735352,  均方误差RMSE=122.74985589402104
# 训练评估：参数,  maxDepth=10,  maxBins=10, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=0.7371165752410889,  均方误差RMSE=92.78990914881749
# 训练评估：参数,  maxDepth=10,  maxBins=15, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=0.9751396179199219,  均方误差RMSE=96.02176637860421
# 训练评估：参数,  maxDepth=10,  maxBins=100, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=0.9091079235076904,  均方误差RMSE=82.12373108157404
# 训练评估：参数,  maxDepth=10,  maxBins=200, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=0.9613251686096191,  均方误差RMSE=82.12373108157404
# 训练评估：参数,  maxDepth=10,  maxBins=500, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=1.0845305919647217,  均方误差RMSE=82.12373108157404

# %%
## 评估参数minInstancesPerNode
maxDepthList = [10]
maxBinsList = [100]
minInstancesPerNodeList=[1,3,5,10,20,50]
minInfoGainList=[0.0]

## 返回结果存放至metries中
metrics = [trainEvaluateModel(trainData, validationData, maxDepth, maxBins, minInstancesPerNode, minInfoGain)
          for maxDepth in maxDepthList
          for maxBins in maxBinsList
          for minInstancesPerNode in minInstancesPerNodeList
          for minInfoGain in minInfoGainList]
# Out:
# 训练评估：参数,  maxDepth=10,  maxBins=100, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=0.8883147239685059,  均方误差RMSE=82.12373108157404
# 训练评估：参数,  maxDepth=10,  maxBins=100, minInstancesPerNode=3, minInfoGainParm=0.0
# ===>消耗时间=0.6935656070709229,  均方误差RMSE=81.73722335547002
# 训练评估：参数,  maxDepth=10,  maxBins=100, minInstancesPerNode=5, minInfoGainParm=0.0
# ===>消耗时间=0.971778392791748,  均方误差RMSE=82.07496111674335
# 训练评估：参数,  maxDepth=10,  maxBins=100, minInstancesPerNode=10, minInfoGainParm=0.0
# ===>消耗时间=0.6591720581054688,  均方误差RMSE=80.851289017033
# 训练评估：参数,  maxDepth=10,  maxBins=100, minInstancesPerNode=20, minInfoGainParm=0.0
# ===>消耗时间=0.6866352558135986,  均方误差RMSE=83.04188316474618
# 训练评估：参数,  maxDepth=10,  maxBins=100, minInstancesPerNode=50, minInfoGainParm=0.0
# ===>消耗时间=0.9950821399688721,  均方误差RMSE=87.04197538973632

# %%
## 评估参数minInfoGain
maxDepthList = [10]
maxBinsList = [100]
minInstancesPerNodeList=[5]
minInfoGainList=[0.0,0.1,0.3,0.5,0.8]

## 返回结果存放至metries中
metrics = [trainEvaluateModel(trainData, validationData, maxDepth, maxBins, minInstancesPerNode, minInfoGain)
          for maxDepth in maxDepthList
          for maxBins in maxBinsList
          for minInstancesPerNode in minInstancesPerNodeList
          for minInfoGain in minInfoGainList]
# Out:
# 训练评估：参数,  maxDepth=10,  maxBins=100, minInstancesPerNode=5, minInfoGainParm=0.0
# ===>消耗时间=0.8632724285125732,  均方误差RMSE=82.07496111674335
# 训练评估：参数,  maxDepth=10,  maxBins=100, minInstancesPerNode=5, minInfoGainParm=0.1
# ===>消耗时间=0.9569089412689209,  均方误差RMSE=82.07496111674335
# 训练评估：参数,  maxDepth=10,  maxBins=100, minInstancesPerNode=5, minInfoGainParm=0.3
# ===>消耗时间=0.8745958805084229,  均方误差RMSE=82.07499118878282
# 训练评估：参数,  maxDepth=10,  maxBins=100, minInstancesPerNode=5, minInfoGainParm=0.5
# ===>消耗时间=0.815180778503418,  均方误差RMSE=82.07503756132985
# 训练评估：参数,  maxDepth=10,  maxBins=100, minInstancesPerNode=5, minInfoGainParm=0.8
# ===>消耗时间=0.8837261199951172,  均方误差RMSE=82.07599663019437

# %%
## 定义函数gridSearch网格搜索最佳参数组合

def gridSearch(trainData, validationData, maxDepthList, maxBinsList, minInstancesPerNodeList, minInfoGainList):
    metrics = [trainEvaluateModel(trainData, validationData, maxDepth, maxBins, minInstancesPerNode, minInfoGain)
          for maxDepth in maxDepthList
          for maxBins in maxBinsList
          for minInstancesPerNode in minInstancesPerNodeList
          for minInfoGain in minInfoGainList]
    # 按照RMSE从小到大排序，返回最小RMSE的参数组合
    sorted_metics = sorted(metrics, key=lambda k:k[0], reverse=False)
    best_parameters = sorted_metics[0]
    print("最佳参数组合："+"maxDepth="+str( best_parameters[2]) + 
         ",  maxBins="+str( best_parameters[3])+",  minInstancesPerNode="+str( best_parameters[4])+
          ", minInfoGain="+str(best_parameters[5])+"\n"+
         ",  均方误差RMSE="+str( best_parameters[0]))
    return  best_parameters
## 参数组合
maxDepthList = [3, 5, 10,20,25]
maxBinsList = [30, 50,100,200]
minInstancesPerNodeList=[1,3,5,10,20]
minInfoGainList=[0.0,0.3,0.5]

## 调用函数返回最佳参数组合
best_parameters = gridSearch(trainData, validationData, maxDepthList, maxBinsList, minInstancesPerNodeList, minInfoGainList)
# Out:
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=0.507742166519165,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=1, minInfoGainParm=0.3
# ===>消耗时间=0.4815943241119385,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=1, minInfoGainParm=0.5
# ===>消耗时间=0.4956505298614502,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=3, minInfoGainParm=0.0
# ===>消耗时间=0.6517014503479004,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=3, minInfoGainParm=0.3
# ===>消耗时间=0.33863282203674316,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=3, minInfoGainParm=0.5
# ===>消耗时间=0.5241448879241943,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=5, minInfoGainParm=0.0
# ===>消耗时间=0.4717533588409424,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=5, minInfoGainParm=0.3
# ===>消耗时间=0.520338773727417,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=5, minInfoGainParm=0.5
# ===>消耗时间=0.4969065189361572,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=10, minInfoGainParm=0.0
# ===>消耗时间=0.33109474182128906,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=10, minInfoGainParm=0.3
# ===>消耗时间=0.6804695129394531,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=10, minInfoGainParm=0.5
# ===>消耗时间=0.49134206771850586,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=20, minInfoGainParm=0.0
# ===>消耗时间=0.35802721977233887,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=20, minInfoGainParm=0.3
# ===>消耗时间=0.5413599014282227,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=30, minInstancesPerNode=20, minInfoGainParm=0.5
# ===>消耗时间=0.6634392738342285,  均方误差RMSE=134.96986696651686
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=0.35141754150390625,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=1, minInfoGainParm=0.3
# ===>消耗时间=0.5459368228912354,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=1, minInfoGainParm=0.5
# ===>消耗时间=0.5169689655303955,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=3, minInfoGainParm=0.0
# ===>消耗时间=0.520301342010498,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=3, minInfoGainParm=0.3
# ===>消耗时间=0.3366081714630127,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=3, minInfoGainParm=0.5
# ===>消耗时间=0.6880617141723633,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=5, minInfoGainParm=0.0
# ===>消耗时间=0.7088220119476318,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=5, minInfoGainParm=0.3
# ===>消耗时间=0.3382260799407959,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=5, minInfoGainParm=0.5
# ===>消耗时间=0.5304815769195557,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=10, minInfoGainParm=0.0
# ===>消耗时间=0.4969494342803955,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=10, minInfoGainParm=0.3
# ===>消耗时间=0.4976069927215576,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=10, minInfoGainParm=0.5
# ===>消耗时间=0.33548450469970703,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=20, minInfoGainParm=0.0
# ===>消耗时间=0.5228900909423828,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=20, minInfoGainParm=0.3
# ===>消耗时间=0.5269322395324707,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=50, minInstancesPerNode=20, minInfoGainParm=0.5
# ===>消耗时间=0.5100691318511963,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=0.4954843521118164,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=1, minInfoGainParm=0.3
# ===>消耗时间=0.5731310844421387,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=1, minInfoGainParm=0.5
# ===>消耗时间=0.5069665908813477,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=3, minInfoGainParm=0.0
# ===>消耗时间=0.3778223991394043,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=3, minInfoGainParm=0.3
# ===>消耗时间=0.6827774047851562,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=3, minInfoGainParm=0.5
# ===>消耗时间=0.3251979351043701,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=5, minInfoGainParm=0.0
# ===>消耗时间=0.39635467529296875,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=5, minInfoGainParm=0.3
# ===>消耗时间=0.7282054424285889,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=5, minInfoGainParm=0.5
# ===>消耗时间=0.5091748237609863,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=10, minInfoGainParm=0.0
# ===>消耗时间=0.6637585163116455,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=10, minInfoGainParm=0.3
# ===>消耗时间=0.48940587043762207,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=10, minInfoGainParm=0.5
# ===>消耗时间=0.5216655731201172,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=20, minInfoGainParm=0.0
# ===>消耗时间=0.5024912357330322,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=20, minInfoGainParm=0.3
# ===>消耗时间=0.48060107231140137,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=100, minInstancesPerNode=20, minInfoGainParm=0.5
# ===>消耗时间=0.5275421142578125,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=200, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=0.3469216823577881,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=200, minInstancesPerNode=1, minInfoGainParm=0.3
# ===>消耗时间=0.5406684875488281,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=200, minInstancesPerNode=1, minInfoGainParm=0.5
# ===>消耗时间=0.5260140895843506,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=200, minInstancesPerNode=3, minInfoGainParm=0.0
# ===>消耗时间=0.6687893867492676,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=200, minInstancesPerNode=3, minInfoGainParm=0.3
# ===>消耗时间=0.5698859691619873,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=200, minInstancesPerNode=3, minInfoGainParm=0.5
# ===>消耗时间=0.5210769176483154,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=200, minInstancesPerNode=5, minInfoGainParm=0.0
# ===>消耗时间=0.5092921257019043,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=200, minInstancesPerNode=5, minInfoGainParm=0.3
# ===>消耗时间=0.481339693069458,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=200, minInstancesPerNode=5, minInfoGainParm=0.5
# ===>消耗时间=0.5347840785980225,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=200, minInstancesPerNode=10, minInfoGainParm=0.0
# ===>消耗时间=0.540454626083374,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=200, minInstancesPerNode=10, minInfoGainParm=0.3
# ===>消耗时间=0.4980590343475342,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=200, minInstancesPerNode=10, minInfoGainParm=0.5
# ===>消耗时间=0.522942304611206,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=200, minInstancesPerNode=20, minInfoGainParm=0.0
# ===>消耗时间=0.5405147075653076,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth=3,  maxBins=200, minInstancesPerNode=20, minInfoGainParm=0.3
# ===>消耗时间=0.5278835296630859,  均方误差RMSE=135.00404144657952
# 训练评估：参数,  maxDepth
# 训练评估：参数,  maxDepth=25,  maxBins=50, minInstancesPerNode=3, minInfoGainParm=0.3
# ===>消耗时间=2.120859146118164,  均方误差RMSE=88.77616763294233
# 训练评估：参数,  maxDepth=25,  maxBins=50, minInstancesPerNode=3, minInfoGainParm=0.5
# ===>消耗时间=2.0365452766418457,  均方误差RMSE=88.77543740302997
# 训练评估：参数,  maxDepth=25,  maxBins=50, minInstancesPerNode=5, minInfoGainParm=0.0
# ===>消耗时间=1.6478893756866455,  均方误差RMSE=83.71300415957303
# 训练评估：参数,  maxDepth=25,  maxBins=50, minInstancesPerNode=5, minInfoGainParm=0.3
# ===>消耗时间=1.5700359344482422,  均方误差RMSE=83.71273394407936
# 训练评估：参数,  maxDepth=25,  maxBins=50, minInstancesPerNode=5, minInfoGainParm=0.5
# ===>消耗时间=1.409843921661377,  均方误差RMSE=83.71290707177913
# 训练评估：参数,  maxDepth=25,  maxBins=50, minInstancesPerNode=10, minInfoGainParm=0.0
# ===>消耗时间=1.2437374591827393,  均方误差RMSE=81.2072794419198
# 训练评估：参数,  maxDepth=25,  maxBins=50, minInstancesPerNode=10, minInfoGainParm=0.3
# ===>消耗时间=1.1571247577667236,  均方误差RMSE=81.20710484533971
# 训练评估：参数,  maxDepth=25,  maxBins=50, minInstancesPerNode=10, minInfoGainParm=0.5
# ===>消耗时间=0.9985036849975586,  均方误差RMSE=81.2070651538379
# 训练评估：参数,  maxDepth=25,  maxBins=50, minInstancesPerNode=20, minInfoGainParm=0.0
# ===>消耗时间=1.107679843902588,  均方误差RMSE=82.16260519294767
# 训练评估：参数,  maxDepth=25,  maxBins=50, minInstancesPerNode=20, minInfoGainParm=0.3
# ===>消耗时间=0.909109354019165,  均方误差RMSE=82.16267621742183
# 训练评估：参数,  maxDepth=25,  maxBins=50, minInstancesPerNode=20, minInfoGainParm=0.5
# ===>消耗时间=0.9536807537078857,  均方误差RMSE=82.16274447929352
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=3.7918784618377686,  均方误差RMSE=97.51405311095507
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=1, minInfoGainParm=0.3
# ===>消耗时间=3.5334935188293457,  均方误差RMSE=97.5155794152798
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=1, minInfoGainParm=0.5
# ===>消耗时间=3.631915330886841,  均方误差RMSE=97.51541728368001
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=3, minInfoGainParm=0.0
# ===>消耗时间=2.154402256011963,  均方误差RMSE=88.10873196146385
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=3, minInfoGainParm=0.3
# ===>消耗时间=2.146134614944458,  均方误差RMSE=88.10835685315536
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=3, minInfoGainParm=0.5
# ===>消耗时间=1.8986454010009766,  均方误差RMSE=88.10762108847328
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=5, minInfoGainParm=0.0
# ===>消耗时间=1.5204830169677734,  均方误差RMSE=83.677120566935
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=5, minInfoGainParm=0.3
# ===>消耗时间=1.7875361442565918,  均方误差RMSE=83.67684846907649
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=5, minInfoGainParm=0.5
# ===>消耗时间=1.630751132965088,  均方误差RMSE=83.67702167102328
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=10, minInfoGainParm=0.0
# ===>消耗时间=1.0035805702209473,  均方误差RMSE=81.64397160081856
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=10, minInfoGainParm=0.3
# ===>消耗时间=1.32729172706604,  均方误差RMSE=81.64381905916505
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=10, minInfoGainParm=0.5
# ===>消耗时间=1.19081711769104,  均方误差RMSE=81.6437795799739
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=20, minInfoGainParm=0.0
# ===>消耗时间=0.9371755123138428,  均方误差RMSE=82.15754781425312
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=20, minInfoGainParm=0.3
# ===>消耗时间=0.9657886028289795,  均方误差RMSE=82.15761423715972
# 训练评估：参数,  maxDepth=25,  maxBins=100, minInstancesPerNode=20, minInfoGainParm=0.5
# ===>消耗时间=0.9657988548278809,  均方误差RMSE=82.15768250323723
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=1, minInfoGainParm=0.0
# ===>消耗时间=3.5329833030700684,  均方误差RMSE=97.51405311095507
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=1, minInfoGainParm=0.3
# ===>消耗时间=3.9077069759368896,  均方误差RMSE=97.5155794152798
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=1, minInfoGainParm=0.5
# ===>消耗时间=3.2992677688598633,  均方误差RMSE=97.51541728368001
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=3, minInfoGainParm=0.0
# ===>消耗时间=2.2399306297302246,  均方误差RMSE=88.10873196146385
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=3, minInfoGainParm=0.3
# ===>消耗时间=2.2729640007019043,  均方误差RMSE=88.10835685315536
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=3, minInfoGainParm=0.5
# ===>消耗时间=2.098609209060669,  均方误差RMSE=88.10762108847328
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=5, minInfoGainParm=0.0
# ===>消耗时间=1.6766972541809082,  均方误差RMSE=83.677120566935
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=5, minInfoGainParm=0.3
# ===>消耗时间=1.6303203105926514,  均方误差RMSE=83.67684846907649
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=5, minInfoGainParm=0.5
# ===>消耗时间=1.468663215637207,  均方误差RMSE=83.67702167102328
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=10, minInfoGainParm=0.0
# ===>消耗时间=1.3703038692474365,  均方误差RMSE=81.64397160081856
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=10, minInfoGainParm=0.3
# ===>消耗时间=1.1580321788787842,  均方误差RMSE=81.64381905916505
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=10, minInfoGainParm=0.5
# ===>消耗时间=1.1953699588775635,  均方误差RMSE=81.6437795799739
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=20, minInfoGainParm=0.0
# ===>消耗时间=0.9872360229492188,  均方误差RMSE=82.15754781425312
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=20, minInfoGainParm=0.3
# ===>消耗时间=0.8008246421813965,  均方误差RMSE=82.15761423715972
# 训练评估：参数,  maxDepth=25,  maxBins=200, minInstancesPerNode=20, minInfoGainParm=0.5
# ===>消耗时间=0.9654159545898438,  均方误差RMSE=82.15768250323723
# 最佳参数组合：maxDepth=20,  maxBins=30,  minInstancesPerNode=20, minInfoGain=0.0
# ,  均方误差RMSE=79.84391359563772
